# %%
from caqtus.device.sequencer.instructions import TimedInstruction, merge_instructions, Pattern

# %%
instr1 = 200 * Pattern([True]) + 500 * Pattern([False]) + 100 * Pattern([True])
instr2 = 700 * Pattern([True]) + 100 * Pattern([False])
instr3 = 200 * Pattern([False]) + 250 * (Pattern([True]) +Pattern([False])) + 100 * Pattern([False])

merge_instructions(ch0=instr1, ch1=instr2, ch2=instr3)
# Out:
# Concatenated(Repeated(repetitions=200, instruction=Pattern([(True, True, False)], dtype=[('ch0', '?'), ('ch1', '?'), ('ch2', '?')])), Repeated(repetitions=250, instruction=Pattern([(False, True, True), (False, True, False)], dtype=[('ch0', '?'), ('ch1', '?'), ('ch2', '?')])), Repeated(repetitions=100, instruction=Pattern([(True, False, False)], dtype=[('ch0', '?'), ('ch1', '?'), ('ch2', '?')])))
