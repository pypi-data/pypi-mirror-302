# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %pip install cellpose==3.0.8

# %%
import os

DATASETS_BASE_PATH = "/content/drive/MyDrive/szakmai gyakorlat/cellpose-cell-counting/datasets"

OLD_FOLDER = "annotated"
CUSTOM_ANNOTATED_FOLDER = "2024.05.09. Ac-kPHSRN+fibronektin-few-annotated"

OLD_DATASET_PATH = os.path.join(DATASETS_BASE_PATH, OLD_FOLDER + ".zip")
CUSTOM_ANNOTATED_DATASET_PATH = os.path.join(DATASETS_BASE_PATH, CUSTOM_ANNOTATED_FOLDER + ".zip")

# %%
# !unzip "{OLD_DATASET_PATH}" -d "/content"
# !unzip "{CUSTOM_ANNOTATED_DATASET_PATH}" -d "/content/{CUSTOM_ANNOTATED_FOLDER}"

# %%
import glob
import numpy as np
import cv2
from PIL import Image

training_images, training_masks = [], []

old_paths = glob.glob(OLD_FOLDER + "/*.jpg")
custom_annotated_paths = glob.glob(CUSTOM_ANNOTATED_FOLDER + "/*.jpg")

for path in old_paths:
  img = cv2.imread(path, 0) # grayscale
  mask = np.load(path.replace(".jpg", "_seg.npy"), allow_pickle=True).item()["masks"]
  training_images.append(img)
  training_masks.append(mask)

for path in custom_annotated_paths:
  img = cv2.imread(path, 0) # grayscale
  mask = np.array(Image.open(path.replace(".jpg", "_mask.tiff")))
  training_images.append(img)
  training_masks.append(mask)

# %%
from cellpose import models, train
from tqdm import trange
import torch
import logging

def train_model(model_type, n_epochs):
  logger = logging.getLogger('cellpose')
  logger.setLevel(logging.DEBUG)

  model = models.CellposeModel(model_type=model_type, gpu=torch.cuda.is_available())

  train.train_seg(
              model.net, n_epochs=n_epochs,
              train_data=training_images, train_labels=training_masks,
              channels=[0, 0], normalize=True,
              weight_decay=1e-4, SGD=True, learning_rate=0.1,
              save_path="/content/drive/MyDrive/szakmai gyakorlat/cellpose-cell-counting", model_name=f"{model_type}_old_annotated")

# %%
train_model("cyto3", n_epochs = 1000)
# Out:
# INFO:cellpose.models:>> cyto3 << model set to be used
# INFO:cellpose.core:** TORCH CUDA version installed and working. **
# INFO:cellpose.core:>>>> using GPU
# INFO:cellpose.models:>>>> loading model /root/.cellpose/models/cyto3
# INFO:cellpose.models:>>>> model diam_mean =  30.000 (ROIs rescaled to this size during training)
# INFO:cellpose.dynamics:computing flows for labels
# 100%|██████████| 27/27 [00:11<00:00,  2.42it/s]
# INFO:cellpose.train:>>> computing diameters
# 100%|██████████| 27/27 [00:00<00:00, 419.49it/s]
# INFO:cellpose.train:>>> using channels [0, 0]
# INFO:cellpose.train:>>> normalizing {'lowhigh': None, 'percentile': None, 'normalize': True, 'norm3D': False, 'sharpen_radius': 0, 'smooth_radius': 0, 'tile_norm_blocksize': 0, 'tile_norm_smooth3D': 1, 'invert': False}
# INFO:cellpose.train:>>> n_epochs=1000, n_train=27, n_test=None
# INFO:cellpose.train:>>> SGD, learning_rate=0.10000, weight_decay=0.00010, momentum=0.900
# INFO:cellpose.train:>>> saving model to /content/drive/MyDrive/szakmai gyakorlat/cellpose-cell-counting/models/cyto3_old_annotated
# INFO:cellpose.train:0, train_loss=2.5181, test_loss=0.0000, LR=0.0000, time 1.09s
# INFO:cellpose.train:5, train_loss=2.1509, test_loss=0.0000, LR=0.0556, time 6.51s
# INFO:cellpose.train:10, train_loss=1.8086, test_loss=0.0000, LR=0.1000, time 12.19s
# INFO:cellpose.train:20, train_loss=1.5711, test_loss=0.0000, LR=0.1000, time 23.43s
# INFO:cellpose.train:30, train_loss=1.5385, test_loss=0.0000, LR=0.1000, time 35.24s
# INFO:cellpose.train:40, train_loss=1.5079, test_loss=0.0000, LR=0.1000, time 47.02s
# INFO:cellpose.train:50, train_loss=1.4612, test_loss=0.0000, LR=0.1000, time 58.56s
# INFO:cellpose.train:60, train_loss=1.4345, test_loss=0.0000, LR=0.1000, time 69.94s
# INFO:cellpose.train:70, train_loss=1.4031, test_loss=0.0000, LR=0.1000, time 81.21s
# INFO:cellpose.train:80, train_loss=1.4184, test_loss=0.0000, LR=0.1000, time 92.49s
# INFO:cellpose.train:90, train_loss=1.3716, test_loss=0.0000, LR=0.1000, time 103.65s
# INFO:cellpose.train:100, train_loss=1.3869, test_loss=0.0000, LR=0.1000, time 114.96s
# INFO:cellpose.train:110, train_loss=1.3332, test_loss=0.0000, LR=0.1000, time 126.61s
# INFO:cellpose.train:120, train_loss=1.3804, test_loss=0.0000, LR=0.1000, time 138.06s
# INFO:cellpose.train:130, train_loss=1.3600, test_loss=0.0000, LR=0.1000, time 149.39s
# INFO:cellpose.train:140, train_loss=1.3357, test_loss=0.0000, LR=0.1000, time 160.47s
# INFO:cellpose.train:150, train_loss=1.3384, test_loss=0.0000, LR=0.1000, time 171.64s
# INFO:cellpose.train:160, train_loss=1.3518, test_loss=0.0000, LR=0.1000, time 182.88s
# INFO:cellpose.train:170, train_loss=1.3155, test_loss=0.0000, LR=0.1000, time 194.21s
# INFO:cellpose.train:180, train_loss=1.3113, test_loss=0.0000, LR=0.1000, time 205.59s
# INFO:cellpose.train:190, train_loss=1.3275, test_loss=0.0000, LR=0.1000, time 216.86s
# INFO:cellpose.train:200, train_loss=1.3384, test_loss=0.0000, LR=0.1000, time 228.06s
# INFO:cellpose.train:210, train_loss=1.2992, test_loss=0.0000, LR=0.1000, time 239.61s
# INFO:cellpose.train:220, train_loss=1.2954, test_loss=0.0000, LR=0.1000, time 251.00s
# INFO:cellpose.train:230, train_loss=1.3178, test_loss=0.0000, LR=0.1000, time 262.37s
# INFO:cellpose.train:240, train_loss=1.2938, test_loss=0.0000, LR=0.1000, time 273.73s
# INFO:cellpose.train:250, train_loss=1.3285, test_loss=0.0000, LR=0.1000, time 284.98s
# INFO:cellpose.train:260, train_loss=1.3087, test_loss=0.0000, LR=0.1000, time 296.34s
# INFO:cellpose.train:270, train_loss=1.2909, test_loss=0.0000, LR=0.1000, time 307.66s
# INFO:cellpose.train:280, train_loss=1.3088, test_loss=0.0000, LR=0.1000, time 319.11s
# INFO:cellpose.train:290, train_loss=1.2870, test_loss=0.0000, LR=0.1000, time 330.51s
# INFO:cellpose.train:300, train_loss=1.2981, test_loss=0.0000, LR=0.1000, time 341.82s
# INFO:cellpose.train:310, train_loss=1.3133, test_loss=0.0000, LR=0.1000, time 353.21s
# INFO:cellpose.train:320, train_loss=1.2773, test_loss=0.0000, LR=0.1000, time 364.63s
# INFO:cellpose.train:330, train_loss=1.3237, test_loss=0.0000, LR=0.1000, time 375.99s
# INFO:cellpose.train:340, train_loss=1.2871, test_loss=0.0000, LR=0.1000, time 387.31s
# INFO:cellpose.train:350, train_loss=1.2960, test_loss=0.0000, LR=0.1000, time 398.74s
# INFO:cellpose.train:360, train_loss=1.2692, test_loss=0.0000, LR=0.1000, time 410.05s
# INFO:cellpose.train:370, train_loss=1.2786, test_loss=0.0000, LR=0.1000, time 421.24s
# INFO:cellpose.train:380, train_loss=1.2684, test_loss=0.0000, LR=0.1000, time 432.71s
# INFO:cellpose.train:390, train_loss=1.2831, test_loss=0.0000, LR=0.1000, time 444.19s
# INFO:cellpose.train:400, train_loss=1.2747, test_loss=0.0000, LR=0.1000, time 455.66s
# INFO:cellpose.train:410, train_loss=1.3122, test_loss=0.0000, LR=0.1000, time 467.12s
# INFO:cellpose.train:420, train_loss=1.2560, test_loss=0.0000, LR=0.1000, time 478.37s
# INFO:cellpose.train:430, train_loss=1.2789, test_loss=0.0000, LR=0.1000, time 489.79s
# INFO:cellpose.train:440, train_loss=1.2595, test_loss=0.0000, LR=0.1000, time 501.11s
# INFO:cellpose.train:450, train_loss=1.2658, test_loss=0.0000, LR=0.1000, time 512.58s
# INFO:cellpose.train:460, train_loss=1.2195, test_loss=0.0000, LR=0.1000, time 524.41s
# INFO:cellpose.train:470, train_loss=1.2927, test_loss=0.0000, LR=0.1000, time 535.70s
# INFO:cellpose.train:480, train_loss=1.2705, test_loss=0.0000, LR=0.1000, time 547.01s
# INFO:cellpose.train:490, train_loss=1.2559, test_loss=0.0000, LR=0.1000, time 558.34s
# INFO:cellpose.train:500, train_loss=1.2412, test_loss=0.0000, LR=0.1000, time 569.74s
# INFO:cellpose.train:510, train_loss=1.2635, test_loss=0.0000, LR=0.1000, time 581.16s
# INFO:cellpose.train:520, train_loss=1.2590, test_loss=0.0000, LR=0.1000, time 592.54s
# INFO:cellpose.train:530, train_loss=1.2267, test_loss=0.0000, LR=0.1000, time 603.79s
# INFO:cellpose.train:540, train_loss=1.2567, test_loss=0.0000, LR=0.1000, time 615.00s
# INFO:cellpose.train:550, train_loss=1.2352, test_loss=0.0000, LR=0.1000, time 626.33s
# INFO:cellpose.train:560, train_loss=1.2633, test_loss=0.0000, LR=0.1000, time 637.62s
# INFO:cellpose.train:570, train_loss=1.2350, test_loss=0.0000, LR=0.1000, time 649.01s
# INFO:cellpose.train:580, train_loss=1.2792, test_loss=0.0000, LR=0.1000, time 660.43s
# INFO:cellpose.train:590, train_loss=1.2410, test_loss=0.0000, LR=0.1000, time 671.59s
# INFO:cellpose.train:600, train_loss=1.2449, test_loss=0.0000, LR=0.1000, time 682.88s
# INFO:cellpose.train:610, train_loss=1.2571, test_loss=0.0000, LR=0.1000, time 694.44s
# INFO:cellpose.train:620, train_loss=1.2573, test_loss=0.0000, LR=0.1000, time 705.81s
# INFO:cellpose.train:630, train_loss=1.2584, test_loss=0.0000, LR=0.1000, time 717.20s
# INFO:cellpose.train:640, train_loss=1.2408, test_loss=0.0000, LR=0.1000, time 728.45s
# INFO:cellpose.train:650, train_loss=1.2515, test_loss=0.0000, LR=0.1000, time 739.51s
# INFO:cellpose.train:660, train_loss=1.2386, test_loss=0.0000, LR=0.1000, time 750.72s
# INFO:cellpose.train:670, train_loss=1.2502, test_loss=0.0000, LR=0.1000, time 762.07s
# INFO:cellpose.train:680, train_loss=1.2550, test_loss=0.0000, LR=0.1000, time 773.46s
# INFO:cellpose.train:690, train_loss=1.2110, test_loss=0.0000, LR=0.1000, time 784.74s
# INFO:cellpose.train:700, train_loss=1.2310, test_loss=0.0000, LR=0.1000, time 796.04s
# INFO:cellpose.train:710, train_loss=1.2785, test_loss=0.0000, LR=0.1000, time 807.37s
# INFO:cellpose.train:720, train_loss=1.2580, test_loss=0.0000, LR=0.1000, time 818.67s
# INFO:cellpose.train:730, train_loss=1.2735, test_loss=0.0000, LR=0.1000, time 829.94s
# INFO:cellpose.train:740, train_loss=1.2777, test_loss=0.0000, LR=0.1000, time 841.28s
# INFO:cellpose.train:750, train_loss=1.2290, test_loss=0.0000, LR=0.1000, time 852.60s
# INFO:cellpose.train:760, train_loss=1.2298, test_loss=0.0000, LR=0.1000, time 863.76s
# INFO:cellpose.train:770, train_loss=1.2351, test_loss=0.0000, LR=0.1000, time 875.05s
# INFO:cellpose.train:780, train_loss=1.2613, test_loss=0.0000, LR=0.1000, time 886.44s
# INFO:cellpose.train:790, train_loss=1.2446, test_loss=0.0000, LR=0.1000, time 897.84s
# INFO:cellpose.train:800, train_loss=1.2510, test_loss=0.0000, LR=0.1000, time 909.18s
# INFO:cellpose.train:810, train_loss=1.2053, test_loss=0.0000, LR=0.1000, time 920.62s
# INFO:cellpose.train:820, train_loss=1.2160, test_loss=0.0000, LR=0.1000, time 931.81s
# INFO:cellpose.train:830, train_loss=1.2143, test_loss=0.0000, LR=0.1000, time 943.16s
# INFO:cellpose.train:840, train_loss=1.2760, test_loss=0.0000, LR=0.1000, time 954.55s
# INFO:cellpose.train:850, train_loss=1.2072, test_loss=0.0000, LR=0.1000, time 965.82s
# INFO:cellpose.train:860, train_loss=1.2157, test_loss=0.0000, LR=0.1000, time 977.32s
# INFO:cellpose.train:870, train_loss=1.2319, test_loss=0.0000, LR=0.1000, time 988.57s
# INFO:cellpose.train:880, train_loss=1.2388, test_loss=0.0000, LR=0.1000, time 999.80s
# INFO:cellpose.train:890, train_loss=1.1904, test_loss=0.0000, LR=0.1000, time 1011.16s
# INFO:cellpose.train:900, train_loss=1.2339, test_loss=0.0000, LR=0.0500, time 1022.46s
# INFO:cellpose.train:910, train_loss=1.2306, test_loss=0.0000, LR=0.0250, time 1033.91s
# INFO:cellpose.train:920, train_loss=1.1827, test_loss=0.0000, LR=0.0125, time 1045.20s
# INFO:cellpose.train:930, train_loss=1.2011, test_loss=0.0000, LR=0.0063, time 1056.31s
# INFO:cellpose.train:940, train_loss=1.2419, test_loss=0.0000, LR=0.0031, time 1067.51s
# INFO:cellpose.train:950, train_loss=1.2210, test_loss=0.0000, LR=0.0016, time 1078.75s
# INFO:cellpose.train:960, train_loss=1.2381, test_loss=0.0000, LR=0.0008, time 1090.11s
# INFO:cellpose.train:970, train_loss=1.2419, test_loss=0.0000, LR=0.0004, time 1101.44s
# INFO:cellpose.train:980, train_loss=1.2052, test_loss=0.0000, LR=0.0002, time 1112.72s
# INFO:cellpose.train:990, train_loss=1.1998, test_loss=0.0000, LR=0.0001, time 1123.93s
