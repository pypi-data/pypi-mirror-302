# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %pip install cellpose==3.0.8

# %%
FOLDER_NAME = "2024.05.09. Ac-kPHSRN+fibronektin-few-annotated"

# !unzip "/content/drive/MyDrive/szakmai gyakorlat/cellpose-cell-counting/datasets/{FOLDER_NAME}.zip" -d "/content/{FOLDER_NAME}"

# %%
import numpy as np
import glob
import cv2
from torch.utils.data import Dataset, random_split
from PIL import Image

file_names = glob.glob(FOLDER_NAME + "/*.jpg")

class ImageDataset(Dataset):
  def __len__(self):
    return len(file_names)

  def __getitem__(self, idx):
    img = cv2.imread(file_names[idx], 0)
    mask = Image.open(file_names[idx].replace(".jpg", "_mask.tiff"))
    return img, np.array(mask)

dataset = ImageDataset()

# %%
training_images, training_masks = [], []

for img, mask in dataset:
  training_images.append(img)
  training_masks.append(mask)

# %%
from cellpose import models, train
from tqdm import trange
import torch
import logging

def train_model(model_type, n_epochs):
  logger = logging.getLogger('cellpose')
  logger.setLevel(logging.DEBUG)

  model = models.CellposeModel(model_type=model_type, gpu=torch.cuda.is_available())

  train.train_seg(
              model.net, n_epochs=n_epochs,
              train_data=training_images, train_labels=training_masks,
              channels=[0, 0], normalize=True,
              weight_decay=1e-4, SGD=True, learning_rate=0.1,
              save_path="/content/drive/MyDrive/szakmai gyakorlat/cellpose-cell-counting", model_name=f"{model_type}_custom_annotated")

# %%
train_model("cyto3", n_epochs = 1000)
# Out:
# INFO:cellpose.models:>> cyto3 << model set to be used
# INFO:cellpose.models:Downloading: "https://www.cellpose.org/models/cyto3" to /root/.cellpose/models/cyto3
#
# 100%|██████████| 25.3M/25.3M [00:03<00:00, 8.64MB/s]
# INFO:cellpose.core:** TORCH CUDA version installed and working. **
# INFO:cellpose.core:>>>> using GPU
# INFO:cellpose.models:>>>> loading model /root/.cellpose/models/cyto3
# INFO:cellpose.models:>>>> model diam_mean =  30.000 (ROIs rescaled to this size during training)
# INFO:cellpose.dynamics:computing flows for labels
# 100%|██████████| 11/11 [00:02<00:00,  4.84it/s]
# INFO:cellpose.train:>>> computing diameters
# 100%|██████████| 11/11 [00:00<00:00, 997.22it/s]
# INFO:cellpose.train:>>> using channels [0, 0]
# INFO:cellpose.train:>>> normalizing {'lowhigh': None, 'percentile': None, 'normalize': True, 'norm3D': False, 'sharpen_radius': 0, 'smooth_radius': 0, 'tile_norm_blocksize': 0, 'tile_norm_smooth3D': 1, 'invert': False}
# INFO:cellpose.train:>>> n_epochs=1000, n_train=11, n_test=None
# INFO:cellpose.train:>>> SGD, learning_rate=0.10000, weight_decay=0.00010, momentum=0.900
# INFO:cellpose.train:>>> saving model to /content/drive/MyDrive/szakmai gyakorlat/cellpose-cell-counting/models/cyto3_custom_annotated
# INFO:cellpose.train:0, train_loss=2.5005, test_loss=0.0000, LR=0.0000, time 1.41s
# INFO:cellpose.train:5, train_loss=2.1234, test_loss=0.0000, LR=0.0556, time 3.24s
# INFO:cellpose.train:10, train_loss=1.6843, test_loss=0.0000, LR=0.1000, time 5.10s
# INFO:cellpose.train:20, train_loss=1.3205, test_loss=0.0000, LR=0.1000, time 8.81s
# INFO:cellpose.train:30, train_loss=1.2157, test_loss=0.0000, LR=0.1000, time 12.59s
# INFO:cellpose.train:40, train_loss=1.1384, test_loss=0.0000, LR=0.1000, time 16.45s
# INFO:cellpose.train:50, train_loss=1.0795, test_loss=0.0000, LR=0.1000, time 20.17s
# INFO:cellpose.train:60, train_loss=1.1292, test_loss=0.0000, LR=0.1000, time 23.89s
# INFO:cellpose.train:70, train_loss=1.0764, test_loss=0.0000, LR=0.1000, time 27.76s
# INFO:cellpose.train:80, train_loss=1.0599, test_loss=0.0000, LR=0.1000, time 31.57s
# INFO:cellpose.train:90, train_loss=1.0523, test_loss=0.0000, LR=0.1000, time 35.41s
# INFO:cellpose.train:100, train_loss=1.0402, test_loss=0.0000, LR=0.1000, time 39.20s
# INFO:cellpose.train:110, train_loss=1.0081, test_loss=0.0000, LR=0.1000, time 45.57s
# INFO:cellpose.train:120, train_loss=1.0809, test_loss=0.0000, LR=0.1000, time 49.32s
# INFO:cellpose.train:130, train_loss=1.0214, test_loss=0.0000, LR=0.1000, time 53.20s
# INFO:cellpose.train:140, train_loss=1.0141, test_loss=0.0000, LR=0.1000, time 57.09s
# INFO:cellpose.train:150, train_loss=1.0168, test_loss=0.0000, LR=0.1000, time 60.86s
# INFO:cellpose.train:160, train_loss=1.0161, test_loss=0.0000, LR=0.1000, time 64.66s
# INFO:cellpose.train:170, train_loss=1.0093, test_loss=0.0000, LR=0.1000, time 68.67s
# INFO:cellpose.train:180, train_loss=0.9514, test_loss=0.0000, LR=0.1000, time 72.48s
# INFO:cellpose.train:190, train_loss=0.9807, test_loss=0.0000, LR=0.1000, time 76.29s
# INFO:cellpose.train:200, train_loss=0.9914, test_loss=0.0000, LR=0.1000, time 80.16s
# INFO:cellpose.train:210, train_loss=0.9993, test_loss=0.0000, LR=0.1000, time 84.27s
# INFO:cellpose.train:220, train_loss=0.9774, test_loss=0.0000, LR=0.1000, time 88.12s
# INFO:cellpose.train:230, train_loss=0.9652, test_loss=0.0000, LR=0.1000, time 92.25s
# INFO:cellpose.train:240, train_loss=0.9773, test_loss=0.0000, LR=0.1000, time 96.29s
# INFO:cellpose.train:250, train_loss=0.9502, test_loss=0.0000, LR=0.1000, time 100.13s
# INFO:cellpose.train:260, train_loss=0.9510, test_loss=0.0000, LR=0.1000, time 103.98s
# INFO:cellpose.train:270, train_loss=0.9558, test_loss=0.0000, LR=0.1000, time 107.91s
# INFO:cellpose.train:280, train_loss=0.9102, test_loss=0.0000, LR=0.1000, time 111.89s
# INFO:cellpose.train:290, train_loss=0.9296, test_loss=0.0000, LR=0.1000, time 115.74s
# INFO:cellpose.train:300, train_loss=0.9663, test_loss=0.0000, LR=0.1000, time 119.93s
# INFO:cellpose.train:310, train_loss=0.9524, test_loss=0.0000, LR=0.1000, time 124.13s
# INFO:cellpose.train:320, train_loss=0.9591, test_loss=0.0000, LR=0.1000, time 128.01s
# INFO:cellpose.train:330, train_loss=0.9239, test_loss=0.0000, LR=0.1000, time 132.00s
# INFO:cellpose.train:340, train_loss=0.9459, test_loss=0.0000, LR=0.1000, time 136.02s
# INFO:cellpose.train:350, train_loss=0.9251, test_loss=0.0000, LR=0.1000, time 140.00s
# INFO:cellpose.train:360, train_loss=0.9535, test_loss=0.0000, LR=0.1000, time 143.88s
# INFO:cellpose.train:370, train_loss=0.9295, test_loss=0.0000, LR=0.1000, time 147.76s
# INFO:cellpose.train:380, train_loss=0.9562, test_loss=0.0000, LR=0.1000, time 151.83s
# INFO:cellpose.train:390, train_loss=0.9377, test_loss=0.0000, LR=0.1000, time 155.74s
# INFO:cellpose.train:400, train_loss=0.9584, test_loss=0.0000, LR=0.1000, time 159.66s
# INFO:cellpose.train:410, train_loss=0.9257, test_loss=0.0000, LR=0.1000, time 163.81s
# INFO:cellpose.train:420, train_loss=0.9427, test_loss=0.0000, LR=0.1000, time 167.79s
# INFO:cellpose.train:430, train_loss=0.9316, test_loss=0.0000, LR=0.1000, time 171.74s
# INFO:cellpose.train:440, train_loss=0.9413, test_loss=0.0000, LR=0.1000, time 175.72s
# INFO:cellpose.train:450, train_loss=0.9233, test_loss=0.0000, LR=0.1000, time 179.93s
# INFO:cellpose.train:460, train_loss=0.9268, test_loss=0.0000, LR=0.1000, time 183.99s
# INFO:cellpose.train:470, train_loss=0.8952, test_loss=0.0000, LR=0.1000, time 187.93s
# INFO:cellpose.train:480, train_loss=0.8848, test_loss=0.0000, LR=0.1000, time 191.99s
# INFO:cellpose.train:490, train_loss=0.9213, test_loss=0.0000, LR=0.1000, time 196.03s
# INFO:cellpose.train:500, train_loss=0.9280, test_loss=0.0000, LR=0.1000, time 199.97s
# INFO:cellpose.train:510, train_loss=0.9328, test_loss=0.0000, LR=0.1000, time 204.09s
# INFO:cellpose.train:520, train_loss=0.9275, test_loss=0.0000, LR=0.1000, time 208.21s
# INFO:cellpose.train:530, train_loss=0.9105, test_loss=0.0000, LR=0.1000, time 212.18s
# INFO:cellpose.train:540, train_loss=0.8956, test_loss=0.0000, LR=0.1000, time 216.13s
# INFO:cellpose.train:550, train_loss=0.9183, test_loss=0.0000, LR=0.1000, time 220.24s
# INFO:cellpose.train:560, train_loss=0.8766, test_loss=0.0000, LR=0.1000, time 224.25s
# INFO:cellpose.train:570, train_loss=0.9045, test_loss=0.0000, LR=0.1000, time 228.24s
# INFO:cellpose.train:580, train_loss=0.8921, test_loss=0.0000, LR=0.1000, time 232.32s
# INFO:cellpose.train:590, train_loss=0.9269, test_loss=0.0000, LR=0.1000, time 236.45s
# INFO:cellpose.train:600, train_loss=0.9128, test_loss=0.0000, LR=0.1000, time 240.48s
# INFO:cellpose.train:610, train_loss=0.8841, test_loss=0.0000, LR=0.1000, time 244.68s
# INFO:cellpose.train:620, train_loss=0.8936, test_loss=0.0000, LR=0.1000, time 248.89s
# INFO:cellpose.train:630, train_loss=0.8700, test_loss=0.0000, LR=0.1000, time 252.96s
# INFO:cellpose.train:640, train_loss=0.9045, test_loss=0.0000, LR=0.1000, time 257.03s
# INFO:cellpose.train:650, train_loss=0.8986, test_loss=0.0000, LR=0.1000, time 261.18s
# INFO:cellpose.train:660, train_loss=0.8778, test_loss=0.0000, LR=0.1000, time 265.27s
# INFO:cellpose.train:670, train_loss=0.8815, test_loss=0.0000, LR=0.1000, time 269.31s
# INFO:cellpose.train:680, train_loss=0.8696, test_loss=0.0000, LR=0.1000, time 273.41s
# INFO:cellpose.train:690, train_loss=0.9089, test_loss=0.0000, LR=0.1000, time 277.54s
# INFO:cellpose.train:700, train_loss=0.8576, test_loss=0.0000, LR=0.1000, time 281.57s
# INFO:cellpose.train:710, train_loss=0.8694, test_loss=0.0000, LR=0.1000, time 285.71s
# INFO:cellpose.train:720, train_loss=0.8865, test_loss=0.0000, LR=0.1000, time 289.90s
# INFO:cellpose.train:730, train_loss=0.8820, test_loss=0.0000, LR=0.1000, time 293.90s
# INFO:cellpose.train:740, train_loss=0.8859, test_loss=0.0000, LR=0.1000, time 297.89s
# INFO:cellpose.train:750, train_loss=0.8859, test_loss=0.0000, LR=0.1000, time 302.01s
# INFO:cellpose.train:760, train_loss=0.8493, test_loss=0.0000, LR=0.1000, time 306.04s
# INFO:cellpose.train:770, train_loss=0.8649, test_loss=0.0000, LR=0.1000, time 310.03s
# INFO:cellpose.train:780, train_loss=0.8853, test_loss=0.0000, LR=0.1000, time 314.11s
# INFO:cellpose.train:790, train_loss=0.8973, test_loss=0.0000, LR=0.1000, time 318.21s
# INFO:cellpose.train:800, train_loss=0.8443, test_loss=0.0000, LR=0.1000, time 322.23s
# INFO:cellpose.train:810, train_loss=0.8600, test_loss=0.0000, LR=0.1000, time 326.40s
# INFO:cellpose.train:820, train_loss=0.8799, test_loss=0.0000, LR=0.1000, time 330.58s
# INFO:cellpose.train:830, train_loss=0.8626, test_loss=0.0000, LR=0.1000, time 334.61s
# INFO:cellpose.train:840, train_loss=0.8378, test_loss=0.0000, LR=0.1000, time 338.65s
# INFO:cellpose.train:850, train_loss=0.8651, test_loss=0.0000, LR=0.1000, time 342.79s
# INFO:cellpose.train:860, train_loss=0.8763, test_loss=0.0000, LR=0.1000, time 346.89s
# INFO:cellpose.train:870, train_loss=0.8862, test_loss=0.0000, LR=0.1000, time 350.96s
# INFO:cellpose.train:880, train_loss=0.8832, test_loss=0.0000, LR=0.1000, time 355.05s
# INFO:cellpose.train:890, train_loss=0.8428, test_loss=0.0000, LR=0.1000, time 359.23s
# INFO:cellpose.train:900, train_loss=0.8687, test_loss=0.0000, LR=0.0500, time 363.27s
# INFO:cellpose.train:910, train_loss=0.8901, test_loss=0.0000, LR=0.0250, time 367.42s
# INFO:cellpose.train:920, train_loss=0.8499, test_loss=0.0000, LR=0.0125, time 371.60s
# INFO:cellpose.train:930, train_loss=0.8501, test_loss=0.0000, LR=0.0063, time 375.64s
# INFO:cellpose.train:940, train_loss=0.8678, test_loss=0.0000, LR=0.0031, time 379.66s
# INFO:cellpose.train:950, train_loss=0.8653, test_loss=0.0000, LR=0.0016, time 383.77s
# INFO:cellpose.train:960, train_loss=0.8591, test_loss=0.0000, LR=0.0008, time 387.86s
# INFO:cellpose.train:970, train_loss=0.8630, test_loss=0.0000, LR=0.0004, time 391.88s
# INFO:cellpose.train:980, train_loss=0.8805, test_loss=0.0000, LR=0.0002, time 395.96s
# INFO:cellpose.train:990, train_loss=0.8750, test_loss=0.0000, LR=0.0001, time 400.12s
